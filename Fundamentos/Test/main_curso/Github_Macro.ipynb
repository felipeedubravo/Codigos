# %%
import time

import pyautogui


pyautogui.PAUSE = 1.5

# Passo a passo do desio
# Passo 1: Endrar no sistema da empresa (link do drive)
    # adrir o chrome
pyautogui.press("win")
pyautogui.write("github Desktop")
pyautogui.press("enter")

time.sleep(2)
pyautogui.click(x=-1582, y=153) 

for ibravo in range(169):
    time.sleep(1.5)
    pyautogui.click(x=-1579, y=181) 
    time.sleep(1.5)
    pyautogui.click(x=-1496, y=791)

# %%
time.sleep(5)
print (pyautogui.position())
# Out:
# Point(x=-1496, y=791)
