# %% [markdown]
# # Exercícios
#
# ## 1. Faturamento do Melhor e do Pior Mês do Ano
#
# Qual foi o valor de vendas do melhor mês do Ano?
# E valor do pior mês do ano?

# %%
meses = ['jan', 'fev', 'mar', 'abr', 'mai', 'jun', 'jul', 'ago', 'set', 'out', 'nov', 'dez']
vendas_1sem = [25000, 29000, 22200, 17750, 15870, 19900]
vendas_2sem = [19850, 20120, 17540, 15555, 49051, 9650]

vendas_1sem.extend(vendas_2sem)
maior_valor = max(vendas_2sem)
mneor_valor = min(vendas_1sem)
print(mneor_valor)
print(maior_valor)
# Out:
# 9650
# 49051

# %% [markdown]
# ## 2. Continuação
#
# Agora relacione as duas listas para printar 'O melhor mês do ano foi {} com {} vendas' e o mesmo para o pior mês do ano.
#
# Calcule também o faturamento total do Ano e quanto que o melhor mês representou do faturamento total.
#
# Obs: Para o faturamento total, pode usar a função sum(lista) que soma todos os itens de uma lista

# %%
i_maior_valor = vendas_1sem.index(maior_valor)
i_mneor_valor = vendas_1sem.index(mneor_valor)

print('O melhor mês do ano foi {} com {} vendas'.format(meses[i_maior_valor],maior_valor))
print('O Pior mês do ano foi {} com {} vendas'.format(meses[i_mneor_valor],mneor_valor))

far_total = sum(vendas_1sem)
print('Faturamento Total: R$ {:,}'.format(far_total))

percentual = maior_valor / far_total
print('O melhor mês representou {:.1%} das vendas do ano todo'.format(percentual))
# Out:
# O melhor mês do ano foi jan com 25000 vendas
# O Pior mês do ano foi out com 9650 vendas
# Faturamento Total: R$ 183,435
# O melhor mês representou 13.6% das vendas do ano todo

# %% [markdown]
# ## 3. Crie uma lista com o top 3 valores de vendas do ano (sem fazer "no olho")
#
# Dica: o método remove retira um item da lista.

# %%
top3 = []
maior_valor = max(vendas_2sem)

print(maior_valor)
top3.append(maior_valor)
print(top3)

#vendas_1sem.remove(maior_valor)
print(vendas_1sem)
maior_valor = max(vendas_1sem)
print(maior_valor)
top3.append(maior_valor)

#vendas_1sem.remove(maior_valor)
print(vendas_1sem)
print(top3)
maior_valor = max(vendas_1sem)
print(maior_valor)
top3.append(maior_valor)

#vendas_1sem.remove(maior_valor)
print(vendas_1sem)
print(top3)
# Out:
# 49051
# [49051]
# [25000, 29000, 22200, 17750, 15870, 19900, 19850, 20120, 17540, 15555, 49051, 9650]
# 49051
# [25000, 29000, 22200, 17750, 15870, 19900, 19850, 20120, 17540, 15555, 49051, 9650]
# [49051, 49051]
# 49051
# [25000, 29000, 22200, 17750, 15870, 19900, 19850, 20120, 17540, 15555, 49051, 9650]
# [49051, 49051, 49051]

# %%
vendas_1sem = [25000, 29000, 22200, 17750, 15870, 19900]
vendas_2sem = [19850, 20120, 17540, 15555, 49051, 9650]

vendas_1sem.extend(vendas_2sem)
maior_valor = max(vendas_2sem)

#menor_valor = min(vendas_1sem)
print(maior_valor)
# Out:
# 49051

# %%
vendas_1sem.sort(reverse=True)
print(vendas_1sem)
# Out:
# [29000, 25000, 22200, 20120, 19900, 19850, 17750, 17540, 15870, 15555, 9650]

# %%
top3 = []

print(maior_valor)
top3.append(maior_valor)
print(top3)

#vendas_1sem.remove(maior_valor)
print(vendas_1sem)
maior_valor = max(vendas_1sem)
print(maior_valor)
top3.append(maior_valor)

print(top3)
# Out:
# 29000
# [29000]
# [25000, 29000, 22200, 17750, 15870, 19900, 19850, 20120, 17540, 15555, 9650]
# 29000
# [29000, 29000]
