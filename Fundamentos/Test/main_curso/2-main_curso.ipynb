# %%
# Condicionais - if elif else
'''
E ae Felipe Bravo, bora dar um saida hoje?
Se ru terminar meu trabalho aqui eu consigo.
'''

trabalho_terminado = True
if trabalho_terminado == True:
    print('Bora!')


trabalho_terminado = False
if trabalho_terminado == True:
    print('Bora!')
else:
    print('Não bora!')

# %%
atrasos = input('Quantos atrasos você tem? ')
atrasos = int(atrasos)

if atrasos >= 3:
    print('voce está inadimplente')
elif atrasos == 2:
    print('mais um dia de atraso')
elif atrasos == 1:
    print('1 dia de atraso')
else:
    print('esta tudo bem')
# Out:
# 1 dia de atraso

# %%
primeiro_valor = input('Digite o 1° valor: ')
segundo_valor = input('Digite o 2° valor: ')
if primeiro_valor > segundo_valor:
    print('o 1° valor é maior')
else:
    print('o 2° valor é maior')
# Out:
# o 2° valor é maior

# %%
# laços de repetição
for item in range(3):
    print(item)
# Out:
# 0
# 1
# 2

# %%
# Lista de nomes
nomes = ['joão','amanda','rafael','carol']
dados = [1,'felipe',True,3.4]
for nome in nomes:
    print(nome)

for dado in dados:
    print(dado)
# Out:
# joão
# amanda
# rafael
# carol
# 1
# felipe
# True
# 3.4

# %%
idades = [13,15,18,30,50,75]
# Exiba somente os maires de idade na tela
for idade in idades:
    if idade >= 18:
        print(idade)
# Out:
# 18
# 30
# 50
# 75

# %%
for idade in idades:
    if idade >= 18:
        print(f'{idade} é maior de idade -^-')
    else:
        print(f'{idade} é menor de idade -X- ')
# Out:
# 13 é menor de idade -X-
# 15 é menor de idade -X-
# 18 é maior de idade -^-
# 30 é maior de idade -^-
# 50 é maior de idade -^-
# 75 é maior de idade -^-

# %%
'''
Exemplo prático com algoritmo real: Validador de senhas
Problema:
Você trabalha em um sistema que precisa verificar se todas as senhas digitadas por usuários são válidas.
Para uma senha ser válida, ela deve ter pelo menos 6 caracteres.
'''
# len(variavel) -> quantidade de caracteres
#len(senha) -> 6 ou não
senhas = ["abc", "segura123", "12345", "python123", "oi"]
for senha in senhas:
    if len(senha) >= 6:
        print(f'A senha (senha) é válida')
    else:
        print (f'A senha (senha) deve possuir no mínimo 6 caracteres')
# Out:
# A senha (senha) deve possuir no mínimo 6 caracteres
# A senha (senha) é válida
# A senha (senha) deve possuir no mínimo 6 caracteres
# A senha (senha) é válida
# A senha (senha) deve possuir no mínimo 6 caracteres

# %%
# While
'''
syntaxe
while condicao:
# código a ser executado
'''
# Criar um programa que permite 3 tentativas, antes de fechar
tentativas = 0
while tentativas < 3:
    print(tentativas)
    print('tente novamente')
    tentativas = tentativas + 1
# Out:
# 0
# tente novamente
# 1
# tente novamente
# 2
# tente novamente

# %%
senha = ''
while senha != '123456':
    senha = input('Digite a senha correta: ')
print('Bem-vindo ao sistema')
# Out:
# Bem-vindo ao sistema

# %%
nome = ''
while nome == '':
    nome = input('Digite seu nome:')
print(f'Bem-vindo {nome}')
# Out:
# Bem-vindo  dfd

# %%
nome = ''
senha = ''

while nome == '':
    nome = input('Digite seu nome:')
print(f'Olá {nome}')
while senha != '123456':
    senha = input('Digite a senha correta: ')
print(f'Bem-vindo ao sistema {nome}')
# Out:
# Olá Felipe Bravo
# Bem-vindo ao sistema Felipe Bravo

# %%
usario = ''
senha = ''
tentativas = 0

while (usario != "Felipe" and senha != "123456") and tentativas < 3:
    usario = input('Digite seu nome:')
    senha = input('Digite a senha correta: ')
    tentativas = tentativas + 1
if usario != "Felipe" and senha != "123456":
    print('aquarde 30 minutos ante de tentar novamente')
else:
    print(f'Bem-vindo ao sistema {usario}')
# Out:
# Bem-vindo ao sistema Felipe
