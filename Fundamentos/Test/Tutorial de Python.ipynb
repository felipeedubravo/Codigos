# %%
# Primeiros passos com Python
print("Olá, Mundo!")
# Out:
# Olá, Mundo!

# %%
# Usa indentação para indicar um bloco de código.
if 5 > 2:
    print("Cinco é maior que dois!")

if 5 > 2:
 print("Cinco é maior que dois!")  

if 5 > 2:
        print("Cinco é maior que dois!")
# Out:
# Cinco é maior que dois!
# Cinco é maior que dois!
# Cinco é maior que dois!

# %%
# Uma variável é criada quando você atribui um valor a ela:
x = 5
y = "Olá, Mundo!"

# %%
# Muitas declarações
# As instruções são executadas uma a uma, na mesma ordem em que são escritas:
# Em Python, o texto deve estar entre aspas. Você pode usar "aspas duplas ou 'aspas simples:
print("Olá, Mundo!")
print('Tenha um bom dia.')
print("Aprender Python é divertido!")
# Out:
# Olá, Mundo!
# Tenha um bom dia.
# Aprender Python é divertido!

# %%
# Ponto e vírgula (opcional, raramente usado)
print("Olá"); print("Como você está?"); print("Tchau!")
# Out:
# Olá
# Como você está?
# Tchau!

# %%
# Por padrão, a print()função termina com uma nova linha.
# Se você quiser imprimir várias palavras na mesma linha, pode usar o endparâmetro:
print("Olá, Mundo!", end=" ")
print("Vou imprimir na mesma linha.")
# Out:
# Olá, Mundo! Vou imprimir na mesma linha.

# %%
# Você também pode usar a print()função para exibir números
# No entanto, ao contrário do texto, não colocamos números entre aspas:
print(3)
print(358)
print(50000)
# Out:
# 3
# 358
# 50000

# %%
# Você também pode realizar cálculos matemáticos dentro da print()função:
print(3 + 3)
print(2 * 5)
# Out:
# 6
# 10

# %%
# Você pode combinar texto e números em uma única saída, separando-os com uma vírgula:
print("Tenho", 34, "anos.")
# Out:
# Tenho 34 anos.

# %%
# Comentários
print("Um brinde, amigo!") # print("Olá, Mundo!")

"""
Este é um comentário
escrito em
mais de uma linha
"""

# %%
# Uma variável é criada no momento em que você atribui um valor a ela pela primeira vez.
x = 5
y = "Felipe"
print(x)
print(y)


x = 4       # x é do tipo int
x = "Bravo" # x agora é do tipo str
print(x)
# Out:
# 5
# Felipe
# Sally

# %%
# Se você deseja especificar o tipo de dados de uma variável, isso pode ser feito por meio de conversão de tipo (casting).
x = str(3)    # x será '3'
y = int(3)    # y será 3
z = float(3)  # z será 3.0

# Você pode obter o tipo de dados de uma variável com a type()função.

x = 5
y = "Felipe"
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# Isso criará duas variáveis:
a = 4
A = "Sally"

# A não sobrescreverá 
print(a)
print(A)
# Out:
# 4
# Sally

# %%
# Python permite atribuir valores a múltiplas variáveis ​​em uma única linha:
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)

# E você pode atribuir o mesmo valor a várias variáveis ​​em uma única linha:
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry
# Orange
# Orange
# Orange

# %%
# Se você tiver uma coleção de valores em um array list, tupleetc., o Python permite extrair esses valores para variáveis. Isso é chamado de desempacotamento .
frutas = ["maçã", "banana", "cereja"]
x, y, z = frutas
print(x)
print(y)
print(z)
# Out:
# maçã
# banana
# cereja

# %%
# A print()função é frequentemente usada para exibir variáveis.
x = "Python é incrível"
print(x)

# Na print()função, você retorna várias variáveis, separadas por vírgula:
x = "Python"
y = "é"
z = "incrível"
print(x, y, z)

# Você também pode usar o +operador para exibir várias variáveis:
x = "Python "
y = "é "
z = "incrível"
print(x + y + z)
# Out:
# Python é incrível
# Python é incrível
# Python é incrível

# %%
# Para números, o +caractere funciona como um operador matemático:
x = 5
y = 10
print(x + y)

# A melhor maneira de exibir várias variáveis ​​na print()função é separá-las com vírgulas, o que inclusive suporta diferentes tipos de dados:
x = 5
y = "Felipe"
print(x, y)
# Out:
# 15
# 5 Felipe

# %%
# Crie uma variável fora de uma função e use-a dentro da função.
x = "incrível"

def minha_função():
  print("Python é " + x)

minha_função()
# Out:
# Python é incrível
# Python é fantástico
# Python é incrível

# %%
# Se você criar uma variável com o mesmo nome dentro de uma função, 
# essa variável será local e só poderá ser usada dentro da função. 
# A variável global com o mesmo nome permanecerá como estava, global e com o valor original.

x = "incrível"

def minha_função2():
  x = "fantástico"
  print("Python é " + x) # isso vai fazer ela mostra o resutado

minha_função2() # Chamou -> def minha_função2(): x = "fantástico" print("Python é " + x)
 
print("Python é " + x)
# Out:
# Python é fantástico
# Python é incrível

# %%
# Se você usar a globalpalavra-chave, a variável pertencerá ao escopo global:

x = "incrível"  # Para alterar o valor de uma variável global dentro de uma função, 
                # faça referência à variável usando a globalpalavra-chave:

def minha_função3():
  global x
  x = "fantástico"

minha_função3() # usa esta função para pode retorna  o "X" global

print("Python é " + x) # para mostra o resutado precisa fazer o "print"
# Out:
# Python é fantástico

# %%
# Imprima o tipo de dados da variável x:
x = "Olá, Mundo"	#str	
print(x)
x = 20	#int
print(x)	
x = 20.5	#float
print(x)	
x = 1j	#complex
print(x)	
x = ["maçã", "banana", "cereja"]	#list	
print(x)
x = ("maçã", "banana", "cereja")	#tuple	
print(x)
x = range(6)	#range	
print(x)
x = {"nome" : "Felipe", "idade" : 34}	#dict	
print(x)
x = {"maçã", "banana", "cereja"}	#set	
print(x)
x = frozenset({"maçã", "banana", "cereja"})	#frozenset	
print(x)
x = True	#bool	
print(x)
x = b"Ola"	#bytes	
print(x)
x = bytearray(5)	#bytearray	
print(x)
x = memoryview(bytes(5))	#memoryview	
print(x)
x = None	#NoneType
print(x)
# Out:
# Olá, Mundo
# 20
# 20.5
# 1j
# ['maçã', 'banana', 'cereja']
# ('maçã', 'banana', 'cereja')
# range(0, 6)
# {'nome': 'Felipe', 'idade': 34}
# {'cereja', 'maçã', 'banana'}
# frozenset({'cereja', 'maçã', 'banana'})
# True
# b'Ola'
# bytearray(b'\x00\x00\x00\x00\x00')
# ...
# None

# %%
# Se você deseja especificar o tipo de dados, pode usar as seguintes funções construtoras:x = str("Hello World")	str	
x = int(20)	#int	
x = float(20.5)	#float	
x = complex(1j)	#complex	
x = list(("maçã", "banana", "cereja"))	#list	
x = tuple(("maçã", "banana", "cereja"))	#tuple	
x = range(6)	#range	
x = dict(name="Felipe", idade=36)	#dict	
x = set(("maçã", "banana", "cereja"))	#set	
x = frozenset(("maçã", "banana", "cereja"))	#frozenset	
x = bool(5)	#bool	
x = bytes(5)	#bytes	
x = bytearray(5)	#bytearray	
x = memoryview(bytes(5))	#memoryview

# %%
# Variáveis ​​de tipo numérico são criadas quando você atribui um valor a elas:

# Int, ou inteiro, é um número inteiro, positivo ou negativo, sem decimais, de comprimento ilimitado.
x = 1 # int
y = 35656222554887711 # int
z = -3255522 # int

# Para verificar o tipo de qualquer objeto em Python, use a type()função:
print(type(x))
print(type(y))
print(type(z))

# Um número de ponto flutuante, ou "float number", é um número, positivo ou negativo, que contém uma ou mais casas decimais.
x = 1.10 #float
y = 1.0 #float
z = -35.59 #float

# Números de ponto flutuante também podem ser números científicos com um "e" para indicar a potência de 10.
a = 35e3 # float
b = 12E4 # float
c = -87.7e100 # float

# Para verificar o tipo de qualquer objeto em Python, use a type()função:
print(type(x))
print(type(y))
print(type(z))
print(type(a))
print(type(b))
print(type(b))

# Os números complexos são escritos com um "j" representando a parte imaginária:
x = 3+5j # complex
y = 5j # complex
z = -5j # complex

# Para verificar o tipo de qualquer objeto em Python, use a type()função:
print(type(x))
print(type(y))
print(type(z))

# Conversão de tipo
# ocê pode converter de um tipo para outro com os métodos int()`convert` float(), `convert` e `convert` complex():
x = 1    # int
y = 2.8  # float
z = 1j   # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)

print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'complex'>
# <class 'complex'>
# <class 'complex'>
# 1.0
# 2
# (1+0j)
# <class 'float'>
# <class 'int'>
# <class 'complex'>

# %%
# Python não possui uma random()função para gerar números aleatórios, mas possui um módulo integrado chamado ` randomrandom` que pode ser usado para isso:
import random

print(random.randrange(1, 10))
# Out:
# 7

# %%
# Um único caractere é simplesmente uma string com comprimento 1.
# Os colchetes podem ser usados ​​para acessar elementos da string.

a = "Oláa, Mundo!"

print(a[0])
print(a[1])
print(a[2])
# Out:
# O
# l
# á

# %%
# Percorrendo uma string em loop
for x in "banana": # Percorra as letras da palavra "banana" em forma de loop
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
# A len()função retorna o comprimento de uma string:
a = "Oláa, Mundo!"
print(len(a))
# Out:
# 12

# %%
# String de verificação
# Para verificar se uma determinada frase ou caractere está presente em uma string, podemos usar a palavra-chave in.
txt = "As melhores coisas da vida são de graça!"
print("de graça" in txt) # Verifique se a palavra "graça" está presente no texto a seguir:

# Imprimir somente se "grátis" estiver presente
txt = "As melhores coisas da vida são de graça!"
if "de graça" in txt:
  print("Sim, 'de graça' está presente.")

# Para verificar se uma determinada frase ou caractere NÃO está presente em uma string, podemos usar a palavra-chave not in
txt = "As melhores coisas da vida são de graça!"
print("caro" not in txt) # Verifique se a palavra "caro" NÃO está presente no texto a seguir:

# Imprimir somente se "caro" NÃO estiver presente:
txt = "As melhores coisas da vida são de graça!"
if "caro" not in txt:
  print("Não, 'caro' NÃO está presente.")
# Out:
# True

# %%
# Você pode retornar um intervalo de caracteres usando a sintaxe de fatiamento.
b = "Oláa, Mundo!"
print(b[2:5])

# Corte desde o início
b = "Oláa, Mundo!"
print(b[:5]) # Obtenha os caracteres do início até a posição 5 (não incluídos)

# Corte até o final
b = "Oláa, Mundo!"
print(b[2:]) # Obtenha os caracteres da posição 2 até o final

# Indexação negativa
b = "Oláa, Mundo!"
print(b[-5:-2]) # Use índices negativos para iniciar o recorte a partir do final da string
# Out:
# áa,
# Oláa,
# áa, Mundo!
# und

# %%
# O upper()método retorna a string em maiúsculas:
a = "Oláa, Mundo!"
print(a.upper())

# O lower()método retorna a string em letras minúsculas:
a = "Oláa, Mundo!!"
print(a.lower())

# Espaço em branco é o espaço antes e/ou depois do texto propriamente dito, e muitas vezes você deseja remover esse espaço.
a = "   Oláa, Mundo!!!  "
print(a.strip()) # retorna "Oláa, Mundo!!!"

# O replace()método substitui uma string por outra string
a = "Oláa, Mundo!!!!"
print(a.replace("O", "J"))
print(a.replace("a", "i"))

# O split()método divide a string em substrings se encontrar ocorrências do separador:
a = "Oláa, Mundo!!!!!"
print(a.split(",")) # returns ['Oláa', ' Mundo!!!!!']
# Out:
# OLÁA, MUNDO!
# oláa, mundo!!
# Oláa, Mundo!!!
# Jláa, Mundo!!!!
# Olái, Mundo!!!!
# ['Oláa', ' Mundo!!!!!']

# %%
# Para concatenar ou combinar duas strings, você pode usar o operador +.
a = "Oláa"
b = "Mundo!"
c = a + b # Mesclar variável 'a' com variável 'b' em variável 'c'
print(c)

# Para adicionar um espaço entre eles, adicione um " " .
a = "Oláa"
b = "Mundo!"
c = a + " " + b
print(c)
# Out:
# OláaMundo!
# Oláa Mundo!

# %%
# Como aprendemos no capítulo sobre variáveis ​​em Python, não podemos combinar strings e números desta forma

''''
idade = 34
# Isso gerará um erro
txt = "Meu nome é Felipe, eu tenho " + idade
print(txt)
'''
#  Basta colocar um 'f' antes da string literal e adicionar chaves {}como marcadores para variáveis ​​e outras operações.
idade = 34
txt = f"Meu nome é Felipe, eu tenho {idade}"
print(txt)
# Out:
# Meu nome é Felipe, eu tenho 34

# %%
# Um marcador de posição pode incluir um modificador para formatar o valor.

# Um modificador é incluído adicionando dois pontos : seguidos por um tipo de formatação válido, como , .2f que significa número de ponto fixo com 2 casas decimais:
preco = 59
txt = f"O preço é R$ {preco:.2f} Reais" # Exiba o preço com 2 casas decimais
print(txt)

# Realize uma operação matemática no espaço reservado e retorne o resultado
txt = f"O preço é R$ {20 * 59} Reais"
print(txt)
# Out:
# O preço é R$ 59.00 Reais
# O preço é R$ 1180 Reais

# %%
# O caractere de escape permite usar aspas duplas em situações onde normalmente não seria permitido

# \'	Aspas simples
txt = "1. Nós somos os chamados \'Vikings\' do norte."
print(txt) 

# \\    Barra invertida
txt = "2.Isso inserirá uma \\ (barra invertida)."
print(txt)

# \n    Nova linha
txt = "3. Olá\nMundo!"
print(txt)

# \r    Carregar Retornar
txt = "Olá \r4. Mundo!" # Cade 'Olá'
print(txt)

# \t    Tab
txt = "5. Olá \tMundo!" 
print(txt)

# \b	Backspace
txt = "6. Olá \bMundo!" # apaga um caractere (backspace)
print(txt)

# \ooo  Octal value
# #Uma barra invertida seguida por três números inteiros resultará em um valor octal:
txt = "7. \157\154\141\040\155\165\156\144\157" # representação em código octal (ASCII)
print(txt) 

# \xhh	Hex value
# Uma barra invertida seguida de um 'x' e um número hexadecimal 
txt = "8. \x6f\x6c\x61\x20\x6d\x75\x6e\x64\x6f" #representa um valor hexadecimal
print(txt)
# Out:
# 1. Nós somos os chamados 'Vikings' do norte.
# 2.Isso inserirá uma \ (barra invertida).
# 3. Olá
# Mundo!
# 4. Mundo!
# 5. Olá 	Mundo!
# 6. OláMundo!
# 7. ola mundo
# 8. ola mundo

# %%
# Métodos de string
# Conjunto de métodos integrados que você pode usar em strings.

exemplo_de_variável = "A string que vai ser alterada"

exemplo_de_variável.capitalize()	# Converte o primeiro caractere para maiúsculo
exemplo_de_variável.casefold()  	# Converte a string para minúsculo
exemplo_de_variável.center()	    # Retorna uma string centralizada
exemplo_de_variável.count()     	# Retorna o número de vezes que um valor especificado ocorre em uma string
exemplo_de_variável.encode()	    # Retorna uma versão codificada da string
exemplo_de_variável.endswith()	    # Retorna True se a string terminar com o valor especificado
exemplo_de_variável.expandtabs()	# Define o tamanho da tabulação da string
exemplo_de_variável.find()          # Busca um valor especificado na string e retorna a posição onde ele foi encontrado
exemplo_de_variável.format()	    # Formata valores especificados em uma string
exemplo_de_variável.format_map()	# Formata valores especificados em uma string
exemplo_de_variável.index()	        # Busca um valor especificado na string e retorna a posição onde ele foi encontrado
exemplo_de_variável.isalnum()	    # Retorna True se todos os caracteres da string forem alfanuméricos
exemplo_de_variável.isalpha()	    # Retorna True se todos os caracteres da string pertencerem ao alfabeto
exemplo_de_variável.isascii()	    # Retorna True se todos os caracteres da string forem caracteres ASCII
exemplo_de_variável.isdecimal() 	# Retorna True se todos os caracteres da string forem decimais
exemplo_de_variável.isdigit()	    # Retorna True se todos os caracteres da string forem dígitos
exemplo_de_variável.isidentifier()	# Retorna True se a string for um identificador
exemplo_de_variável.islower()	    # Retorna True se todos os caracteres da string estiverem em minúsculo
exemplo_de_variável.isnumeric() 	# Retorna True se todos os caracteres da string forem numéricos
exemplo_de_variável.isprintable()	# Retorna True se todos os caracteres da string forem imprimíveis
exemplo_de_variável.isspace()	    # Retorna True se todos os caracteres da string forem espaços em branco
exemplo_de_variável.istitle()	    # Retorna True se a string seguir as regras de um título
exemplo_de_variável.isupper()	    # Retorna True se todos os caracteres da string estiverem em letras maiúsculas
exemplo_de_variável.join()          # Une os elementos de um iterável ao final da string
exemplo_de_variável.ljust() 	    # Retorna uma versão da string alinhada à esquerda
exemplo_de_variável.lower()	        # Converte uma string para letras minúsculas
exemplo_de_variável.lstrip()	    # Retorna uma versão da string sem espaços à esquerda
exemplo_de_variável.maketrans()	    # Retorna uma tabela de tradução para ser usada em traduções
exemplo_de_variável.partition()	    # Retorna uma tupla na qual a string é dividida em três partes
exemplo_de_variável.replace()   	# Retorna uma string onde um valor especificado é substituído por outro valor especificado
exemplo_de_variável.rfind()     	# Busca um valor especificado na string e retorna a última posição onde ele foi encontrado
exemplo_de_variável.rindex()    	# Busca um valor especificado na string e retorna a última posição onde ele foi encontrado
exemplo_de_variável.rjust()     	# Retorna uma versão da string alinhada à direita
exemplo_de_variável.rpartition()	# Retorna uma tupla na qual a string é dividida em três partes
exemplo_de_variável.rsplit()	    # Divide a string no separador especificado e retorna uma lista
exemplo_de_variável.rstrip()	    # Retorna uma versão da string sem espaços à direita
exemplo_de_variável.split()         # Divide a string no separador especificado e retorna uma lista
exemplo_de_variável.splitlines()	# Divide a string nas quebras de linha e retorna uma lista
exemplo_de_variável.startswith()	# Retorna True se a string começar com o valor especificado
exemplo_de_variável.strip()	        # Retorna uma versão da string sem espaços nas extremidades
exemplo_de_variável.swapcase()	    # Inverte as maiúsculas e minúsculas; minúsculas viram maiúsculas e vice-versa
exemplo_de_variável.title()	        # Converte o primeiro caractere de cada palavra para maiúsculo
exemplo_de_variável.translate()     # Retorna uma string traduzida
exemplo_de_variável.upper()	        # Converte uma string para letras maiúsculas
exemplo_de_variável.zfill()         # Preenche a string com uma quantidade especificada de zeros no início

# Observação: Todos os métodos de string retornam novos valores. Eles não alteram a string original

# %%
# Create the variable
txt =  "Hello, World!"
# Print characters from index 2 to 5
print(txt[2:5])
# Print in upper case
print(txt.upper())
# Create the name variable
name = "Python"
# Print using an f-string
print(f"I Love {name}")
# Out:
#   Cell In[1], line 4
#     print(x[2:5})
#                ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '['

# %%
print('Banco de Teste')
print("--------------")

saldo = 500
um = 'Saldo'
dois = 'Saque'
tres = 'Extrato'
quatro = 'Chat'
cinco = 'Sair'

cpf = input('Digite seu CPF: ')
senha = input('Digite sua senha: ')

if cpf == 1000 and senha == 1234:
    print('Um - Saldo')
    print('Dois - Saque')
    print('Três - EXtrato')
    print('Quatro - Chat')
    print('Cinco - Sair')
    input(print('Digite a opção desejada: '))
if um :
    print('Seu saldo é de R$500,00')
elif dois:
    s1 = input('Digite o valor do saque: ')
    saque = 500 - s1
    print('dois')
elif tres:
    print('tres')
elif quatro:
    print('quatros')
else:
    print('Obrigodo por utilizar o Banco de teste!')
# Out:
# Banco de Teste
# --------------
# Seu saldo é de R$500,00

# %%
print('Banco de Teste')
print("--------------")

saldo = 500
um = 'Saldo'
dois = 'Saque'
tres = 'Extrato'
quatro = 'Chat'
cinco = 'Sair'

cpf = input('Digite seu CPF: ')
senha = input('Digite sua senha: ')
if cpf and senha :
    if cpf == '1000':
        if senha == '1234':
            print('Um - Saldo')
# Out:
# Banco de Teste
# --------------
# Um - Saldo

# %%
produto = input('Qual o produto?')
categoria = input('Qual a categoria do produto?')
qtde = int(input('qual a quantidade atual do produto'))

if produto and categoria and qtde:
    
    if categoria == 'bebidas':
        if qtde < 75:
            print('Solicitar {} á equipe de compreas, temos apanas unidades em estoque'.format(produto, qtde))
    elif categoria == "limpeza":    
        if qtde < 30:
            print('Solicitar {} á equipe de compreas, temos apanas unidades em estoque'.format(produto, qtde))
    else:    
        if qtde < 50:
            print('Solicitar {} á equipe de compreas, temos apanas unidades em estoque'.format(produto, qtde))
else:
    print('Preencha todas as informações')

# %%
print('Banco de Teste')
print("--------------")

saldo = 500.0

cpf = input('Digite seu CPF: ')
senha = input('Digite sua senha: ')

# Ajuste 1: Comparando com textos (usando aspas)
if cpf == '1000' and senha == '1234':
    print('\n1 - Saldo')
    print('2 - Saque')
    print('3 - Extrato')
    print('4 - Chat')
    print('5 - Sair')
    
    # Ajuste 2: Guardando a resposta em uma variável
    opcao = input('Digite a opção desejada (1 a 5): ')
    
    # Ajuste 3: Tudo isso precisa estar "indentado" (com espaço) para acontecer só se o login der certo
    if opcao == '1':
        print(f'\nSeu saldo é de R$ {saldo}')
        
    elif opcao == '2':
        # Ajuste 4: Transformando o texto digitado em número decimal (float)
        s1 = float(input('Digite o valor do saque: '))
        if s1 <= saldo:
            saldo = saldo - s1
            print(f'\nSaque de R$ {s1} realizado com sucesso!')
            print(f'Seu novo saldo é R$ {saldo}')
        else:
            print('\nSaldo insuficiente!')
            
    elif opcao == '3':
        print('\nSeu extrato está vazio.')
        
    elif opcao == '4':
        print('\nIniciando atendimento via chat...')
        
    elif opcao == '5':
        print('\nSaindo da conta...')
        
    else:
        print('\nOpção inválida!')
        
else:
    print('\nCPF ou senha incorretos.')

print('\nObrigado por utilizar o Banco de Teste!')
# Out:
# Banco de Teste
# --------------
#
# 1 - Saldo
# 2 - Saque
# 3 - Extrato
# 4 - Chat
# 5 - Sair
#
# Iniciando atendimento via chat...
#
# Obrigado por utilizar o Banco de Teste!

# %%
import os
os.system("clear") # Limpa o terminal antes de rodar

print("\n")
print("               *** LENDAS DO AÇAÍ ***")
print("\n")

# Atribuindo os produtos
produto1 = "Açaí Tradicional 500ml"
produto2 = "Copo da Lenda 700ml"
produto3 = "Adicional de Leite Ninho"

# Atribuindo os valores unitários dos produtos
unitario1 = 18.50
unitario2 = 28.90
unitario3 = 3.50

# Definindo a quantidade dos produtos
qtd1 = 2
qtd2 = 1
qtd3 = 3

# Calculando o valor parcial dos produtos
parcial1 = qtd1 * unitario1
parcial2 = qtd2 * unitario2
parcial3 = qtd3 * unitario3

# Calculando o valor final
valor_final = parcial1 + parcial2 + parcial3

# Função pontinhos: acrescenta pontos no final de cada produto
def pontinhos(prod: str) -> str:
    # (Tamanho máximo - tamanho do produto) => tot. pontinhos
    return (27 - len(prod)) * '.'

# Exibindo os dados do pedido COM formatações
print("PRODUTO                    | QTD | UNITARIO | PARCIAL")
print("-------------------------------------------------------")

print(f"{produto1+pontinhos(produto1)} | {qtd1:03} | " +
      f"R$ {unitario1:6.2f} | R$ {parcial1:6.2f}")

print(f"{produto2+pontinhos(produto2)} | {qtd2:03} | " +
      f"R$ {unitario2:6.2f} | R$ {parcial2:6.2f}")

print(f"{produto3+pontinhos(produto3)} | {qtd3:03} | " +
      f"R$ {unitario3:6.2f} | R$ {parcial3:6.2f}")


print("-------------------------------------------------------")
print(f"{' ' * 35}Valor Final: R$ {valor_final:6.2f}\n")
# Out:
#                *** LENDAS DO AÇAÍ ***
#
#
# PRODUTO                    | QTD | UNITARIO | PARCIAL
# -------------------------------------------------------
# Açaí Tradicional 500ml..... | 002 | R$  18.50 | R$  37.00
# Copo da Lenda 700ml........ | 001 | R$  28.90 | R$  28.90
# Adicional de Leite Ninho... | 003 | R$   3.50 | R$  10.50
# -------------------------------------------------------
#                                    Valor Final: R$  76.40

# %%
import pandas as pd
import numpy as np

# Criando um DataFrame de exemplo
data = {
    'Salario': [50000, 60000, 70000, 80000, 90000],
    'Idade': [25, 30, 35, 40, 45]
}
df = pd.DataFrame(data)

# Calculando funções estatísticas básicas
media_salario = df['Salario'].mean()
mediana_idade = df['Idade'].median()
variancia_salario = df['Salario'].var()
desvio_padrao_idade = df['Idade'].std()

print(f"Média do Salário: {media_salario}")
print(f"Mediana da Idade: {mediana_idade}")
print(f"Variância do Salário: {variancia_salario}")
print(f"Desvio Padrão da Idade: {desvio_padrao_idade}")

# Calculando correlação de Pearson
correlacao = df.corr(method='pearson')
print("\nCorrelação de Pearson:")
print(correlacao)
# Out:
# Média do Salário: 70000.0
# Mediana da Idade: 35.0
# Variância do Salário: 250000000.0
# Desvio Padrão da Idade: 7.905694150420948
#
# Correlação de Pearson:
#          Salario  Idade
# Salario      1.0    1.0
# Idade        1.0    1.0
